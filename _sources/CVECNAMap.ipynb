# %% [markdown]
# # CNA MAP
# ---

# %%
from IPython.core.magic import register_cell_magic
from IPython.display import Markdown
import datetime
from datetime import date
import folium
from folium.plugins import MarkerCluster
from geopy.geocoders import Nominatim
import json
import pandas as pd
import time

# %%
with open('CNAsList.json') as f:
    data = json.load(f)

CNA = pd.json_normalize(data)

geolocator = Nominatim(user_agent="CNALookup")
latitude = []
long = []
for i in CNA["country"]:
    if i != None:
        location = geolocator.geocode(i, timeout=None)
        if location!=None:
            latitude.append(location.latitude)#, location.longitude)
            long.append(location.longitude)
        else:
            latitude.append(float("Nan"))#, location.longitude)
            long.append(float("Nan"))
    else:
        latitude.append(float("Nan"))#, location.longitude)
        long.append(float("Nan"))

CNA["Latitude"] = latitude
CNA["Longitude"] = long

# %%
pattern = r'(https?:\/\/(?:www\.)?[-a-zA-Z0-9@:%._+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}[-a-zA-Z0-9()@:%_+.~#?&/=]*)' 
CNA['securityAdvisories.advisories'] = CNA['securityAdvisories.advisories'].astype(str)
CNA['URL'] = CNA['securityAdvisories.advisories'].str.extract(pattern, expand=False).str.strip()
CNA['URL'] = CNA['URL'].astype(str)

# %%
map = folium.Map(location=[10, 0], tiles='cartodb positron', zoom_start=2.25)

mcluster = MarkerCluster().add_to(map)

for index, row in CNA.iterrows():
    folium.Marker(location=[row['Latitude'],row['Longitude']], popup=("<b>"+row.organizationName+"</b>" +"\n"+"<br>"+row.URL),icon=folium.Icon(color='lightgray', icon='bug', prefix='fa')).add_to(mcluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e642445372f0de070e7867ebae3e0cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e642445372f0de070e7867ebae3e0cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e642445372f0de070e7867ebae3e0cb = L.map(
#                 &quot;map_3e642445372f0de070e7867ebae3e0cb&quot;,
#                 {
#                     center: [10.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2.25,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70712f7e4d346c1d9b78618af0c7703b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70712f7e4d346c1d9b78618af0c7703b.addTo(map_3e642445372f0de070e7867ebae3e0cb);
#
#
#             var marker_cluster_ff94ae618fb2728064a3ed65741e2852 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_16eb179b8d1ff363405ae73625710c44 = L.marker(
#                 [39.7837304, -100.445882],
#                 {
# }
#             ).addTo(marker_cluster_ff94ae618fb2728064a3ed65741e2852);
#
#
#             var icon_2175f3d7cd29cedfa71fc778f1b06270 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightgray&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bug&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_16eb179b8d1ff363405ae73625710c44.setIcon(icon_2175f3d7cd29cedfa71fc778f1b06270);
#
#
#         var popup_03a46eb36c50eebd63a6335d78df4da4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4366af05e3800a68129e4c2568e031f8 = $(`&lt;div id=&quot;html_4366af05e3800a68129e4c2568e031f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Adobe Systems Incorporated&lt;/b&gt; &lt;br&gt;https://helpx.adobe.com/security.html&lt;/div&gt;`)[0];
#                 popup_03a46eb36c50eebd63a6335d78df4da4.setContent(html_4366af05e3800a68129e4c2568e031f8);
#
#
#
#         marker_16eb179b8d1ff363405ae73625710c44.bindPopup(popup_03a46eb36c50eebd63a6335d78df4da4)
#         ;
#
#
#
#
#             var marker_a6ad94d2457003c605a189a6162a1793 = L.marker(
#                 [39.7837304, -100.445882],
#                 {
# }
#             ).addTo(marker_cluster_ff94ae618fb2728064a3ed65741e2852);
#
#
#             var icon_332f51a1fac53ab02fd5a2727a1f3cb8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightgray&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bug&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a6ad94d2457003c605a189a6162a1793.setIcon(icon_332f51a1fac53ab02fd5a2727a1f3cb8);
#
#
#         var popup_83a0552a379464b063f5885d6fe2743d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0415b35805f85fdda46c5cfae31814b2 = $(`&lt;div id=&quot;html_0415b35805f85fdda46c5cfae31814b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Advanced Micro Devices Inc.&lt;/b&gt; &lt;br&gt;https://www.amd.com/en/resources/product-security.html#security&lt;/div&gt;`)[0];
#                 popup_83a0552a379464b063f5885d6fe2743d.setContent(html_0415b35805f85fdda46c5cfae31814b2);
#
#
#
#         marker_a6ad94d2457003c605a189a6162a1793.bindPopup(popup_83a0552a379464b063f5885d6fe2743d)
#         ;
#
#
#
#
#             var marker_3e10b2dd37fa32bd7b705a6d9cc9a907 = L.marker(
#                 [52.2434979, 5.6343227],
#                 {
# }
#             ).addTo(marker_cluster_ff94ae618fb2728064a3ed65741e2852);
#
#
#             var icon_f8e53950818cb9b536c93f177390b6f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;lightgray&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bug&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3e10b2dd37fa32bd7b705a6d9cc9a907.setIcon(icon_f8e53950818cb9b536c93f177390b6f5);
#
#
#         var popup_f1b5af65bee5b1a536c254190892b706 = L.

# %% [markdown]
# This map is built from the data on [this page](https://www.cve.org/PartnerInformation/ListofPartners). More infomration about CNA's can be found [here](https://www.cve.org/ProgramOrganization/CNAs).

# %%
Markdown(f"This report is updated automatically every day, last generated on: **{datetime.datetime.now()}**")
# Out:
# This report is updated automatically every day, last generated on: **2025-02-18 12:25:22.563987**
