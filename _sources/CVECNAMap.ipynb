# %% [markdown]
# # CNA MAP
# ---

# %%
from IPython.core.magic import register_cell_magic
from IPython.display import Markdown
import datetime
from datetime import date
import folium
from folium.plugins import MarkerCluster
from geopy.geocoders import Nominatim
import json
import pandas as pd
import time

# %%
with open('CNAsList.json') as f:
    data = json.load(f)

CNA = pd.json_normalize(data)

geolocator = Nominatim(user_agent="CNALookup")
latitude = []
long = []
for i in CNA["country"]:
    if i != None:
        location = geolocator.geocode(i, timeout=None)
        if location!=None:
            latitude.append(location.latitude)#, location.longitude)
            long.append(location.longitude)
        else:
            latitude.append(float("Nan"))#, location.longitude)
            long.append(float("Nan"))
    else:
        latitude.append(float("Nan"))#, location.longitude)
        long.append(float("Nan"))

CNA["Latitude"] = latitude
CNA["Longitude"] = long

# %%
pattern = r'(https?:\/\/(?:www\.)?[-a-zA-Z0-9@:%._+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}[-a-zA-Z0-9()@:%_+.~#?&/=]*)' 
CNA['securityAdvisories.advisories'] = CNA['securityAdvisories.advisories'].astype(str)
CNA['URL'] = CNA['securityAdvisories.advisories'].str.extract(pattern, expand=False).str.strip()
CNA['URL'] = CNA['URL'].astype(str)

# %%
map = folium.Map(location=[10, 0], tiles='cartodb positron', zoom_start=2.25)

mcluster = MarkerCluster().add_to(map)

for index, row in CNA.iterrows():
    folium.Marker(location=[row['Latitude'],row['Longitude']], popup=("<b>"+row.organizationName+"</b>" +"\n"+"<br>"+row.URL),icon=folium.Icon(color='lightgray', icon='bug', prefix='fa')).add_to(mcluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ca53bc42b543deeed295fb398dd4f27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ca53bc42b543deeed295fb398dd4f27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ca53bc42b543deeed295fb398dd4f27 = L.map(
#                 &quot;map_6ca53bc42b543deeed295fb398dd4f27&quot;,
#                 {
#                     center: [10.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2.25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13aaff0c0c1fce60c2a7b788a09a25bf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_13aaff0c0c1fce60c2a7b788a09a25bf.addTo(map_6ca53bc42b543deeed295fb398dd4f27);
#
#
#             var marker_cluster_3cea3b4f3fe9ffabeed22023ce850490 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_d690b6fc7ef66f7b403ddd46ea618c95 = L.marker(
#                 [39.7837304, -100.445882],
#                 {}
#             ).addTo(marker_cluster_3cea3b4f3fe9ffabeed22023ce850490);
#
#
#             var icon_e622baac7bca2dea2e60af124c55d9a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bug&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d690b6fc7ef66f7b403ddd46ea618c95.setIcon(icon_e622baac7bca2dea2e60af124c55d9a6);
#
#
#         var popup_0f193f9e0d2b345228eaffe3ac93c26b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6d9b456ee83a9179c7edd4900230f48 = $(`&lt;div id=&quot;html_b6d9b456ee83a9179c7edd4900230f48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Adobe Systems Incorporated&lt;/b&gt; &lt;br&gt;https://helpx.adobe.com/security.html&lt;/div&gt;`)[0];
#                 popup_0f193f9e0d2b345228eaffe3ac93c26b.setContent(html_b6d9b456ee83a9179c7edd4900230f48);
#
#
#
#         marker_d690b6fc7ef66f7b403ddd46ea618c95.bindPopup(popup_0f193f9e0d2b345228eaffe3ac93c26b)
#         ;
#
#
#
#
#             var marker_ae90193c1d00aa46d918c5b048ec071d = L.marker(
#                 [39.7837304, -100.445882],
#                 {}
#             ).addTo(marker_cluster_3cea3b4f3fe9ffabeed22023ce850490);
#
#
#             var icon_5ffa53b9df7babb925469875178c0be7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bug&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ae90193c1d00aa46d918c5b048ec071d.setIcon(icon_5ffa53b9df7babb925469875178c0be7);
#
#
#         var popup_c077255809194f97239c9f73536a11f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4cfe2f02f451f2b6aa5bf6dd31b098d = $(`&lt;div id=&quot;html_c4cfe2f02f451f2b6aa5bf6dd31b098d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Advanced Micro Devices Inc.&lt;/b&gt; &lt;br&gt;https://www.amd.com/en/corporate/product-security&lt;/div&gt;`)[0];
#                 popup_c077255809194f97239c9f73536a11f8.setContent(html_c4cfe2f02f451f2b6aa5bf6dd31b098d);
#
#
#
#         marker_ae90193c1d00aa46d918c5b048ec071d.bindPopup(popup_c077255809194f97239c9f73536a11f8)
#         ;
#
#
#
#
#             var marker_3cc125fc3e3fdd3d795e7e268166faf9 = L.marker(
#                 [52.2434979, 5.6343227],
#                 {}
#             ).addTo(marker_cluster_3cea3b4f3fe9ffabeed22023ce850490);
#
#
#             var icon_222eb399cd3d485e42f73781d3117f13 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bug&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3cc125fc3e3fdd3d795e7e268166faf9.setIcon(icon_222eb399cd3d485e42f73781d3117f13);
#
#
#         var popup_f2aeecf8ba9162a6d557afd82b875131 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a4cbb3fc

# %% [markdown]
# This map is built from the data on [this page](https://www.cve.org/PartnerInformation/ListofPartners). More infomration about CNA's can be found [here](https://www.cve.org/ProgramOrganization/CNAs).

# %%
Markdown(f"This report is updated automatically every day, last generated on: **{datetime.datetime.now()}**")
# Out:
# This report is updated automatically every day, last generated on: **2024-05-21 16:14:28.940306**
